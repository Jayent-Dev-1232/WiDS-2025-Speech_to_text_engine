# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

y, sr = librosa.load("D:\Projects\Winter_in_Data_Science\WiDS-2025-Speech_to_text_engine\Week 4\data\speech_commands\yes\0a7c2a8d_nohash_0.wav")

plt.figure(figsize=(12,3))
librosa.display.waveshow(y, sr=sr)
plt.title("Waveform")
plt.show()
